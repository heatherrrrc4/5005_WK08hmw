# %% [markdown]
# # Homework08
#
# Some exercises with text files and string manipulation
#
# ## Goals
#
# - Get familiar with how strings work in Python
# - Practice processing text files

# %% [markdown]
# ## Import helpers
#
# Run the following cell to import helper functions, files and libraries

# %%
from string import ascii_lowercase
from Homework08_utils import Homework08_utils

# %%
with open("./data/astronomy.txt", "r") as f:
    text = f.read()

print(text[:200])
# Out:
# Astronomy in the medieval Islamic world
#
# Medieval Islamic astronomy comprises the astronomical developments made in the Islamic world, particularly during the Islamic Golden Age (9th–13th centuries),

# %%
files = ["astrolabe.txt", "astronomy.txt", "astrovandalista.txt"]

for fname in files:
    with open("./data/" + fname, "r") as f:
        text = f.read()
        print(fname, "length:", len(text))
# Out:
# astrolabe.txt length: 18957
# astronomy.txt length: 32303
# astrovandalista.txt length: 21784

# %% [markdown]
# ## A little review
#
# Before we get into the deep of the exercises, just a little review about strings and/as lists.
#
# Strings are like lists. Most of the functions we use on lists (`len()`, `sorted()`, `reversed()`, etc) work on strings. And indexing (positive and negative) as well as slicing, work the same.
#
# We can concatenate strings and append to strings using $+$:
#
# ```py
# # concatenate
# my_str = "it was the" + " best thing"
#
# # append
# my_str += " ever"
# ```
#
# <br><br>Some operations or processing of strings might end up giving us a list of characters in the end (`reversed()` and `sorted()`, for example).
#
# ```py
# print(sorted("once upon"))
# >>> [' ', 'c', 'e', 'n', 'n', 'o', 'o', 'p', 'u']
# ```
#
# <br><br>In these cases, we can turn the list of characters back into a string with `join()`, but the syntax is a little less intuitive than most Python functions and feels backwards:
#
# ```py
# "".join(list_of_characters)
# ```
#
# <br><br>It's like this because you can use it to add any separator between items of anything that is _iterable_:
# ```py
# ", ".join(["apple", "pineapple", "banana", "pen"])
# ```
#
# <br><br>Turning a string into a list of characters is easy and intuitive:
# ```py
# list("once upon a time")
# ```

# %% [markdown]
# ### TL;DR
#
# ##### string to list of characters: `list(string_variable)`
#
# ##### list of characters to string: `"".join(char_list)`

# %% [markdown]
# ## Secrets
#
# We've discovered some secret messages left by a mathematician inside a book.
#
# We can see all of the messages here: `Homework08_utils.MSGS`, but there's some strong evidence that suggests that they are connected and that decoding the first one will help decode the second one and so on...
#
# ### Secret 0
#
# Let's look at the first message:

# %%
print(Homework08_utils.MSGS[0])
# Out:
# uif ofyu nfttbhf xbt fodpefe vtjoh uif tbnf tusbufhz bt uijt pof, cvu xjui b mbshfs tijgu bnpvou.
# uifsf bsf pomz 26 qpttjcjmjujft, tp ... nbzcf bo bvupnbujd xbz pg uszjoh bmm qpttjcjmjujft xpvme ifmq ...

# %% [markdown]
# #### _Cesar Cipher_
#
# A team of code breakers and cryptographers has suggested that we start by trying to decode the message using a [_Cesar Cipher_](https://en.wikipedia.org/wiki/Caesar_cipher) transformation.
#
# This is a simple form of encoding/decoding where the characters are just shifted by a predetermined amount, but their relative order stays the same.
#
# So, if the letter `D` has been encoded as `A`, the letter `E` will be `B`, and so on.
#
# <div style="padding:30px 20px; background-color:#fff; display:block; width:600px;" >
#   <img src="./imgs/caesar-cipher.png" width=600>
# </div>
#
# Let's try it out with a shift of $1$. Write some code that iterates over the message and decodes the letters by shifting them back by $1$ position: the letter `u` becomes `t`, `i` becomes `h`, `f` becomes `e`, etc ...
#
# #### Practical Cesar
#
# We have imported the `ascii_lowercase` member variable from the `string` library. This variable holds all of the lowercase letters of the roman alphabet in order, as a string: `abcdefghijklmnopqrstuvwxyz`.
#
# This means we can get a letter at a specific location by indexing into this string with `[ ]`, and, conversely,  we can find the index of a letter by using the `index()` function:
#
# ```py
# ascii_lowercase[7]
# >>> "i"
#
# ascii_lowercase[-1]
# >>> "z"
#
# ascii_lowercase.index("a")
# >>> 0
#
# ascii_lowercase.index("b")
# >>> 1
# ```

# %%
# TODO: decode the first message assuming it was created using a Cesar cipher of 1
# TODO: characters not in ascii_lowercase stay the same and don't have to be decoded
def caesar_decode(text):
    decoded = ""

    for char in text:
        if char in ascii_lowercase:
            index = ascii_lowercase.index(char)
            new_index = (index - 1) % 26   # shift back by 1
            decoded += ascii_lowercase[new_index]
        else:
            decoded += char 

    return decoded

decoded_msg = caesar_decode(Homework08_utils.MSGS[0])
print(decoded_msg)
# Out:
# the next message was encoded using the same strategy as this one, but with a larger shift amount.
# there are only 26 possibilities, so ... maybe an automatic way of trying all possibilities would help ...

# %% [markdown]
# ### Secret 1
#
# Ok. A hint !
#
# Let's look at the message:

# %%
print(Homework08_utils.MSGS[1])
# Out:
# ylhk aol khah/hzayvshil.aea mpsl. thrl pa svdly jhzl. jvbua slaaly mylxblujf.
# bzl aol vykly av kljvkl aol ulea alea:
# aol tvza mylxblua slaaly pu aol zljyla tlzzhnl jvyylzwvukz av aol tvza mylxblua slaaly pu aol alea mpsl,
# aol zljvuk tvza mylxblua slaaly pu aol zljyla pz aol zljvuk tvza mylxblua slaaly pu aol alea mpsl,
# huk zv vu...

# %% [markdown]
# #### Funct-ify it
#
# It could help if we wrapped the code we used above inside a function that takes the shift amount as a parameter.

# %%
# TODO: turn the code from above into a function that takes a parameter for the amount of un-shifting

def uncesar(txt, amt):
    msg = ""

    for char in txt:
        if char in ascii_lowercase:
            index = ascii_lowercase.index(char)
            new_index = (index - amt) % 26
            msg += ascii_lowercase[new_index]
        else:
            msg += char

    return msg

# %% [markdown]
# #### Test it on the first message with a shift of $1$

# %%
print(uncesar(Homework08_utils.MSGS[0], 1))
# Out:
# the next message was encoded using the same strategy as this one, but with a larger shift amount.
# there are only 26 possibilities, so ... maybe an automatic way of trying all possibilities would help ...

# %%
for i in range(26):
    print("Shift:", i)
    print(uncesar(Homework08_utils.MSGS[1], i))
    print("-----")
# Out:
# Shift: 0
# ylhk aol khah/hzayvshil.aea mpsl. thrl pa svdly jhzl. jvbua slaaly mylxblujf.
# bzl aol vykly av kljvkl aol ulea alea:
# aol tvza mylxblua slaaly pu aol zljyla tlzzhnl jvyylzwvukz av aol tvza mylxblua slaaly pu aol alea mpsl,
# aol zljvuk tvza mylxblua slaaly pu aol zljyla pz aol zljvuk tvza mylxblua slaaly pu aol alea mpsl,
# uif tfdpoe nptu gsfrvfou mfuufs jo uif tfdsfu jt uif tfdpoe nptu gsfrvfou mfuufs jo uif ufyu gjmf,
# boe tp po...
# -----
# Shift: 7
# read the data/astrolabe.txt file. make it lower case. count letter frequency.
# use the order to decode the next text:
# the most frequent letter in the secret message corresponds to the most frequent letter in the text file,
# the second most frequent letter in the secret is the second most frequent letter in the text file,
# and so on...
# -----
# Shift: 8
# qdzc sgd czsz/zrsqnkzad.sws ehkd. lzjd hs knvdq bzrd. bntms kdssdq eqdptdmbx.
# trd sgd nqcdq sn cdbncd sgd mdws sdws:
# sgd lnrs eqdptdms kdssdq hm sgd rdbqds ldrrzfd bnqqdronmcr sn sgd lnrs eqdptdms kdssdq hm sgd sdws ehkd,
# sgd rdbnmc lnrs eqdptdms kdssdq hm sgd rdbqds hr sgd rdbnmc lnrs eqdptdms kdssdq hm sgd sdws ehkd,
# zmc rn nm...
# -----
# Shift: 9
# pcyb rfc byry/yqrpmjyzc.rvr dgjc. kyic gr jmucp ayqc. amslr jcrrcp dpcosclaw.
# sqc rfc mpbcp rm bcambc rfc lcvr rcvr:
# rfc kmqr dpcosclr jcrrcp gl rfc qcapcr kcqqyec amppcqnmlbq rm rfc kmqr dpcosclr jcrrcp gl rfc rcvr dgjc,
# rfc qcamlb kmqr dpcosclr jcrrcp gl rfc qcapcr gq rfc qcamlb kmqr dpcosclr jcrrcp gl rfc rcvr dgjc,
# ylb qm ml...
# -----
# Shift: 10
# obxa qeb axqx/xpqolixyb.quq cfib. jxhb fq iltbo zxpb. zlrkq ibqqbo cobnrbkzv.
# rpb qeb loabo ql abzlab qeb kbuq qbuq:
# qeb jlpq cobnrbkq ibqqbo fk qeb pbzobq jbppxdb zloobpmlkap ql qeb jlpq cobnrbkq ibqqbo fk qeb qbuq cfib,
# qeb pbzlka jlpq cobnrbkq ibqqbo fk qeb pbzobq fp qeb pbzlka jlpq cobnrbkq ibqqbo fk qeb qbuq cfib,
# xka pl lk...
# -----
# Shift: 11
# nawz pda zwpw/wopnkhwxa.ptp beha. iwga ep hksan ywoa. ykqjp happan bnamqajyu.
# qoa pda knzan pk zaykza pda jatp patp:
# pda ikop bnamqajp happan ej pda oaynap iaoowca yknnaolkjzo pk pda ikop bnamqajp happan ej pda patp beha,
# pda oaykjz ikop bnamqajp happan ej pda oaynap eo pda oaykjz ikop bnamqajp happan ej pda patp beha,
# wjz ok kj...
# -----
# Shift: 12
# mzvy ocz yvov/vnomjgvwz.oso adgz. hvfz do gjrzm xvnz. xjpio gzoozm amzlpzixt.
# pnz ocz jmyzm oj yzxjyz ocz izso ozso:
# ocz hjno amzlpzio gzoozm di ocz nzxmzo hznnvbz xjmmznkjiyn oj ocz hjno amzlpzio gzoozm di ocz ozso adgz,
# ocz nzxjiy hjno amzlpzio gzoozm di ocz nzxmzo dn ocz nzxjiy hjno amzlpzio gzoozm di ocz ozso adgz,
# viy nj ji...
# -----
# Shift: 13
# lyux nby xunu/umnlifuvy.nrn zcfy. guey cn fiqyl wumy. wiohn fynnyl zlykoyhws.
# igs hvs cfrsf hc rsqcrs hvs bslh hslh:
# hvs acgh tfseisbh zshhsf wb hvs gsqfsh asggous qcffsgdcbrg hc hvs acgh tfseisbh zshhsf wb hvs hslh twzs,
# hvs gsqcbr acgh tfseisbh zshhsf wb hvs gsqfsh wg hvs gsqcbr acgh tfseisbh zshhsf wb hvs hslh twzs,
# obr gc cb...
# -----
# Shift: 20
# ernq gur qngn/nfgebynor.gkg svyr. znxr vg ybjre pnfr. pbhag yrggre serdhrapl.
# hfr gur beqre gb qrpbqr gur arkg grkg:
# gur zbfg serdhrag yrggre va gur frperg zrffntr pbeerfcbaqf gb gur zbfg serdhrag yrggre va gur grkg svyr,
# gur frpbaq zbfg serdhrag yrggre va gur frperg vf gur frpbaq zbfg serdhrag yrggre va gur grkg svyr,
# naq fb ba...
# -----
# Shift: 21
# dqmp ftq pmfm/mefdaxmnq.fjf ruxq. ymwq uf xaiqd omeq. oagzf xqffqd rdqcgqzok.
# geq ftq adpqd fa pqoapq ftq zqjf fqjf:
# ftq yaef rdqcgqzf xqffqd uz ftq eqodqf yqeemsq oaddqebazpe fa ftq yaef rdqcgqzf xqffqd uz ftq fqjf ruxq,
# ftq eqoazp yaef rdqcgqzf xqffqd uz ftq eqodqf ue ftq eqoazp yaef rdqcgqzf xqffqd uz ftq fqjf ruxq,
# mzp ea az...
# -----
# Shift: 22
# cplo esp olel/ldeczwlmp.eie qtwp. xlvp te wzhpc nldp. nzfye wpeepc qcpbfpynj.
# fdp esp zcopc ez opnzop esp ypie epie:
# esp xzde qcpbfpye wpeepc ty esp dpncpe xpddlrp nzccpdazyod ez esp xzde qcpbfpye wpeepc ty esp epie qtwp,
# esp dpnzyo xzde qcpbfpye wpeepc ty esp dpncpe td esp dpnzyo xzde qcpbfpye wpeepc ty esp epie qtwp,
# lyo dz zy...
# -----
# Shift: 23
# bokn dro nkdk/kcdbyvklo.dhd psvo. wkuo sd vygob mkco. myexd voddob pboaeoxmi.
# eco dro ybnob dy nomyno dro xohd dohd:
# dro wycd pboaeoxd voddob sx dro combod wocckqo mybboczyxnc dy dro wycd pboaeoxd voddob sx dro dohd psvo,
# dro comyxn wycd pboaeoxd voddob sx dro combod sc dro comyxn wycd pboaeoxd voddob sx dro dohd psvo,
# kxn cy yx...
# -----
# Shift: 24
# anjm cqn mjcj/jbcaxujkn.cgc orun. vjtn rc uxfna ljbn. lxdwc unccna oanzdnwlh.
# dbn cqn xamna cx mnlxmn cqn wngc cngc:
# cqn vxbc oanzdnwc unccna rw cqn bnlanc vnbbjpn lxaanbyxwmb cx cqn vxbc oanzdnwc unccna rw cqn cngc orun,
# cqn bnlxwm vxbc oanzdnwc unccna rw cqn bnlanc rb cqn bnlxwm vxbc oanzdnwc unccna rw cqn cngc orun,
# jwm bx xw...
# -----
# Shift: 25
# zmil bpm libi/iabzwtijm.bfb nqtm. uism qb twemz kiam. kwcvb tmbbmz nzmycmvkg.
# cam bpm wzlmz bw lmkwlm bpm vmfb bmfb:
# bpm uwab nzmycmvb tmbbmz qv bpm amkzmb umaaiom kwzzmaxwvla bw bpm uwab nzmycmvb tmbbmz qv bpm bmfb nqtm,
# bpm amkwvl uwab nzmycmvb tmbbmz qv bpm amkzmb qa bpm amkwvl uwab nzmycmvb tmbbmz qv bpm bmfb nqtm,
# ivl aw wv...
# -----

# %% [markdown]
# #### Loop time
#
# Test all possible $25$ shifts and see which one (if any) produces a legible message.
#
# (it's $25$ because we know it's not a shift of $0$, and a shift of $26$ wraps around and is the same as a shift of $0$)

# %%
# TODO: use the function on the encrypted message until we get something that looks decrypted.

for i in range(1, 26):  
    decoded = uncesar(Homework08_utils.MSGS[1], i)
    
    print("\n====== Shift:", i, "======")
    print(decoded)
# Out:
# ====== Shift: 1 ======
# xkgj znk jgzg/gyzxurghk.zdz lork. sgqk oz ruckx igyk. iuatz rkzzkx lxkwaktie.
# ayk znk uxjkx zu jkiujk znk tkdz zkdz:
# znk suyz lxkwaktz rkzzkx ot znk ykixkz skyygmk iuxxkyvutjy zu znk suyz lxkwaktz rkzzkx ot znk zkdz lork,
# znk ykiutj suyz lxkwaktz rkzzkx ot znk ykixkz oy znk ykiutj suyz lxkwaktz rkzzkx ot znk zkdz lork,
# gtj yu ut...
#
# ====== Shift: 2 ======
# wjfi ymj ifyf/fxywtqfgj.ycy knqj. rfpj ny qtbjw hfxj. htzsy qjyyjw kwjvzjshd.
# zxj ymj twijw yt ijhtij ymj sjcy yjcy:
# ymj rtxy kwjvzjsy qjyyjw ns ymj xjhwjy rjxxflj htwwjxutsix yt ymj rtxy kwjvzjsy qjyyjw ns ymj yjcy knqj,
# ymj xjhtsi rtxy kwjvzjsy qjyyjw ns ymj xjhwjy nx ymj xjhtsi rtxy kwjvzjsy qjyyjw ns ymj yjcy knqj,
# fsi xt ts...
#
# ====== Shift: 3 ======
# vieh xli hexe/ewxvspefi.xbx jmpi. qeoi mx psaiv gewi. gsyrx pixxiv jviuyirgc.
# ywi xli svhiv xs higshi xli ribx xibx:
# xli qswx jviuyirx pixxiv mr xli wigvix qiwweki gsvviwtsrhw xs xli qswx jviuyirx pixxiv mr xli xibx jmpi,
# xli wigsrh qswx jviuyirx pixxiv mr xli wigvix mw xli wigsrh qswx jviuyirx pixxiv mr xli xibx jmpi,
# erh ws sr...
#
# ====== Shift: 4 ======
# uhdg wkh gdwd/dvwurodeh.waw iloh. pdnh lw orzhu fdvh. frxqw ohwwhu iuhtxhqfb.
# xvh wkh rughu wr ghfrgh wkh qhaw whaw:
# wkh prvw iuhtxhqw ohwwhu lq wkh vhfuhw phvvdjh fruuhvsrqgv wr wkh prvw iuhtxhqw ohwwhu lq wkh whaw iloh,
# wkh vhfrqg prvw iuhtxhqw ohwwhu lq wkh vhfuhw lv wkh vhfrqg prvw iuhtxhqw ohwwhu lq wkh whaw iloh,
# dqg vr rq...
#
# ====== Shift: 5 ======
# tgcf vjg fcvc/cuvtqncdg.vzv hkng. ocmg kv nqygt ecug. eqwpv ngvvgt htgswgpea.
# wug vjg qtfgt vq fgeqfg vjg pgzv vgzv:
# vjg oquv htgswgpv ngvvgt kp vjg ugetgv oguucig eqttgurqpfu vq vjg oquv htgswgpv ngvvgt kp vjg vgzv hkng,
# vjg ugeqpf oquv htgswgpv ngvvgt kp vjg ugetgv ku vjg ugeqpf oquv htgswgpv ngvvgt kp vjg vgzv hkng,
# cpf uq qp...
#
# ====== Shift: 6 ======
# sfbe uif ebub/btuspmbcf.uyu gjmf. nblf ju mpxfs dbtf. dpvou mfuufs gsfrvfodz.
# vtf uif psefs up efdpef uif ofyu ufyu:
# uif nptu gsfrvfou mfuufs jo uif tfdsfu nfttbhf dpssftqpoet up uif nptu gsfrvfou mfuufs jo uif ufyu gjmf,
# uif tfdpoe nptu gsfrvfou mfuufs jo uif tfdsfu jt uif tfdpoe nptu gsfrvfou mfuufs jo uif ufyu gjmf,
# boe tp po...
#
# ====== Shift: 7 ======
# read the data/astrolabe.txt file. make it lower case. count letter frequency.
# use the order to decode the next text:
# the most frequent letter in the secret message corresponds to the most frequent letter in the text file,
# the second most frequent letter in the secret is the second most frequent letter in the text file,
# and so on...
#
# ====== Shift: 8 ======
# qdzc sgd czsz/zrsqnkzad.sws ehkd. lzjd hs knvdq bzrd. bntms kdssdq eqdptdmbx.
# trd sgd nqcdq sn cdbncd sgd mdws sdws:
# sgd lnrs eqdptdms kdssdq hm sgd rdbqds ldrrzfd bnqqdronmcr sn sgd lnrs eqdptdms kdssdq hm sgd sdws ehkd,
# sgd rdbnmc lnrs eqdptdms kdssdq hm sgd rdbqds hr sgd rdbnmc lnrs eqdptdms kdssdq hm sgd sdws ehkd,
# zmc rn nm...
#
# ====== Shift: 9 ======
# pcyb rfc byry/yqrpmjyzc.rvr dgjc. kyic gr jmucp ayqc. amslr jcrrcp dpcosclaw.
# sqc rfc mpbcp rm bcambc rfc lcvr rcvr:
# rfc kmqr dpcosclr jcrrcp gl rfc qcapcr kcqqyec amppcqnmlbq rm rfc kmqr dpcosclr jcrrcp gl rfc rcvr dgjc,
# rfc qcamlb kmqr dpcosclr jcrrcp gl rfc qcapcr gq rfc qcamlb kmqr dpcosclr jcrrcp gl rfc rcvr dgjc,
# ylb qm ml...
#
# ====== Shift: 10 ======
# obxa qeb axqx/xpqolixyb.quq cfib. jxhb fq iltbo zxpb. zlrkq ibqqbo cobnrbkzv.
# rpb qeb loabo ql abzlab qeb kbuq qbuq:
# qeb jlpq cobnrbkq ibqqbo fk qeb pbzobq jbppxdb zloobpmlkap ql qeb jlpq cobnrbkq ibqqbo fk qeb qbuq cfib,
# qeb pbzlka jlpq cobnrbkq ibqqbo fk qeb pbzobq fp qeb pbzlka jlpq cobnrbkq ibqqbo fk qeb qbuq cfib,
# xka pl lk...
#
# ====== Shift: 11 ======
# nawz pda zwpw/wopnkhwxa.ptp beha. iwga ep hksan ywoa. ykqjp happan bnamqajyu.
# qoa pda knzan pk zaykza pda jatp patp:
# pda ikop bnamqajp happan ej pda oaynap iaoowca yknnaolkjzo pk pda ikop bnamqajp happan ej pda patp beha,
# jxu iusedt ceij vhugkudj bujjuh yd jxu iushuj yi jxu iusedt ceij vhugkudj bujjuh yd jxu junj vybu,
# qdt ie ed...
#
# ====== Shift: 18 ======
# gtps iwt spip/phigdapqt.imi uxat. bpzt xi adltg rpht. rdjci atiitg ugtfjtcrn.
# jht iwt dgstg id strdst iwt ctmi itmi:
# iwt bdhi ugtfjtci atiitg xc iwt htrgti bthhpvt rdggthedcsh id iwt bdhi ugtfjtci atiitg xc iwt itmi uxat,
# iwt htrdcs bdhi ugtfjtci atiitg xc iwt htrgti xh iwt htrdcs bdhi ugtfjtci atiitg xc iwt itmi uxat,
# pcs hd dc...
#
# ====== Shift: 19 ======
# fsor hvs roho/oghfczops.hlh twzs. aoys wh zcksf qogs. qcibh zshhsf tfseisbqm.
# igs hvs cfrsf hc rsqcrs hvs bslh hslh:
# hvs acgh tfseisbh zshhsf wb hvs gsqfsh asggous qcffsgdcbrg hc hvs acgh tfseisbh zshhsf wb hvs hslh twzs,
# hvs gsqcbr acgh tfseisbh zshhsf wb hvs gsqfsh wg hvs gsqcbr acgh tfseisbh zshhsf wb hvs hslh twzs,
# obr gc cb...
#
# ====== Shift: 20 ======
# ernq gur qngn/nfgebynor.gkg svyr. znxr vg ybjre pnfr. pbhag yrggre serdhrapl.
# hfr gur beqre gb qrpbqr gur arkg grkg:
# gur zbfg serdhrag yrggre va gur frperg zrffntr pbeerfcbaqf gb gur zbfg serdhrag yrggre va gur grkg svyr,
# gur frpbaq zbfg serdhrag yrggre va gur frperg vf gur frpbaq zbfg serdhrag yrggre va gur grkg svyr,
# naq fb ba...
#
# ====== Shift: 21 ======
# dqmp ftq pmfm/mefdaxmnq.fjf ruxq. ymwq uf xaiqd omeq. oagzf xqffqd rdqcgqzok.
# geq ftq adpqd fa pqoapq ftq zqjf fqjf:
# ftq yaef rdqcgqzf xqffqd uz ftq eqodqf yqeemsq oaddqebazpe fa ftq yaef rdqcgqzf xqffqd uz ftq fqjf ruxq,
# ftq eqoazp yaef rdqcgqzf xqffqd uz ftq eqodqf ue ftq eqoazp yaef rdqcgqzf xqffqd uz ftq fqjf ruxq,
# mzp ea az...
#
# ====== Shift: 22 ======
# cplo esp olel/ldeczwlmp.eie qtwp. xlvp te wzhpc nldp. nzfye wpeepc qcpbfpynj.
# fdp esp zcopc ez opnzop esp ypie epie:
# esp xzde qcpbfpye wpeepc ty esp dpncpe xpddlrp nzccpdazyod ez esp xzde qcpbfpye wpeepc ty esp epie qtwp,
# esp dpnzyo xzde qcpbfpye wpeepc ty esp dpncpe td esp dpnzyo xzde qcpbfpye wpeepc ty esp epie qtwp,
# lyo dz zy...
#
# ====== Shift: 23 ======
# bokn dro nkdk/kcdbyvklo.dhd psvo. wkuo sd vygob mkco. myexd voddob pboaeoxmi.
# eco dro ybnob dy nomyno dro xohd dohd:
# dro wycd pboaeoxd voddob sx dro combod wocckqo mybboczyxnc dy dro wycd pboaeoxd voddob sx dro dohd psvo,
# dro comyxn wycd pboaeoxd voddob sx dro combod sc dro comyxn wycd pboaeoxd voddob sx dro dohd psvo,
# kxn cy yx...
#
# ====== Shift: 24 ======
# anjm cqn mjcj/jbcaxujkn.cgc orun. vjtn rc uxfna ljbn. lxdwc unccna oanzdnwlh.
# dbn cqn xamna cx mnlxmn cqn wngc cngc:
# cqn vxbc oanzdnwc unccna rw cqn bnlanc vnbbjpn lxaanbyxwmb cx cqn vxbc oanzdnwc unccna rw cqn cngc orun,
# cqn bnlxwm vxbc oanzdnwc unccna rw cqn bnlanc rb cqn bnlxwm vxbc oanzdnwc unccna rw cqn cngc orun,
# jwm bx xw...
#
# ====== Shift: 25 ======
# zmil bpm libi/iabzwtijm.bfb nqtm. uism qb twemz kiam. kwcvb tmbbmz nzmycmvkg.
# cam bpm wzlmz bw lmkwlm bpm vmfb bmfb:
# bpm uwab nzmycmvb tmbbmz qv bpm amkzmb umaaiom kwzzmaxwvla bw bpm uwab nzmycmvb tmbbmz qv bpm bmfb nqtm,
# bpm amkwvl uwab nzmycmvb tmbbmz qv bpm amkzmb qa bpm amkwvl uwab nzmycmvb tmbbmz qv bpm bmfb nqtm,
# ivl aw wv...

# %%
# shift 7 gets the correct decoded message!

# %%
# ====== Shift: 7 ======
# read the data/astrolabe.txt file. make it lower case. count letter frequency.
# use the order to decode the next text:
# the most frequent letter in the secret message corresponds to the most frequent letter in the text file,
# the second most frequent letter in the secret is the second most frequent letter in the text file,
# and so on...

# %% [markdown]
# ### Secret 2
#
# ## 🎉
# Another hint !
#
# Let's look at the next message:

# %%
print(Homework08_utils.MSGS[2])
# Out:
# fe fnhby, eh nyuha. ktllyr zfiiyvre atuu ygyvoy utpy f eymvyi gyuhlx.
# akfi eyygyl mkfhitm atuu vybyfu tie vkxikg, ostltro xhsv lymtethre atik mufvtix.
# zfx fiiyrithr ih esniuy etorfue fe ikyx mfvvx iky ivsik nyryfik iky esvjfmy.
# <|tgfoy|>
# ...
# <|tgfoy|>
# <|yrl hj gyeefoy | torhvy fjiyv ikte|>
# ytgvulzgghrhiugvtkfqviasryoswvrno mctgtaefhrkwok ... ... ... ... vrlujzyuyeibzkomunouvmvfvigajycdlcmdovfyirnlrlaspoilfhmhvydsfhofrqfzohntuogleenjqykirjrretfygvvhylbdanirtnldycyymerymlcldhobnvu ... ...  ...  gvbyniirnbtysrroxmkrlctllasqybfcsetrr  ... aupkhttkhlrrsrtlivpnhmjmdhkgzbzxftunvfafrwuzrmomrrtvythsqsyfifyvnkhgvathgufwivulrmttrnxukvgceoljiluafvoqflltxlf ... ...  ... ... ... ... ... ... ... ...

# %% [markdown]
# ## 🤦
#
# At least we have a hint.
#
# Let's start by opening up the file, turning everything into lowercase, and counting the occurrence of each letter.
#
# We'll do the same for the encoded text. Maybe a function will help... but since it's just $2$ texts we can do it without a function too.
#
# A dictionary can help keep track of letter counts:
# ```py
# counts = {
#   "a": 0,
#   "b": 12,
#   ...
# }
# ```
#
# Or, we can use a list of lists, initially ordered by alphabetical order:
# ```py
# counts = [ ["a", 0], ["b", 12], ... ]
# ```
#
# If something is not in `ascii_lowercase` we'll just skip it.

# %%
# TODO: count occurrences in the source text file and in the encoded message

# %% [markdown]
# #### Sort the letters by occurrence
#
# Either most to least frequent or least to most. We just have to be consistent.
#
# If a dictionary was used in the previous step, we have to turn it into a list of `[letter, count]` pairs before sorting it:
# ```py
# letter_count_list = []
# for ltr,cnt in letter_count_dict.items():
#   letter_count_list.append([ltr,cnt])
# ```
#
# And sorting can then be done with a key function that looks at the second term of each `[letter, count]` pair:
# ```py
# def byCount(LC):
#   ltr,cnt = LC
#   return cnt
#   # OR
#   return LC[1]
# ```
#
# After sorting them, we can get rid of the counts and keep just $2$ lists of letters, one for the source file and one for the secret message.

# %%
# TODO: sort the letters by occurrence
# TODO: discard the counts, and only keep the letters

# %% [markdown]
# #### Create a decoder
#
# We have two ordered lists of letters, and we want to be able to use the relative order of the letters in both lists to perform a type of letter replacement.
#
# So, every time we see `t` in the encoded message, we'll look up the index of `t` in the list of letters from the encoded message, and then use this index to get the replacement letter in the ordered list of letters from the text file we read.
#
# Something like:
# ```py
# text_order[secret_order.index(L)]
# ```
#
# And, as always, we'll skip characters that are not in the `ascii_lowercase` list.

# %%
# TODO: decode message by using the index of each letter in one list to get a letter from second list

# %% [markdown]
# ## 🎉
# Hooray ! Message decoded !
#
# ### Bonus
#
# There are some funny looking characters at the end of the message.
#
# They were added in order to ensure the letter occurrences in the message matched the letter occurrences of the plain text file.
#
# But... there is a special portion of the decoded text, sandwiched between `<|image|>` separators, that IS part of the message.
#
# This looks like the [$\text{Base}64$](https://en.wikipedia.org/wiki/Base64) encoding we saw in `Homework07`, but it's actually [$\text{Base}32$](https://en.wikipedia.org/wiki/Base32), which is the same, but doesn't differentiate between upper and lower case letters.
#
# Let's `split()` the decoded message and extract this special string and pass it onto the `Homework08_utils.b32_to_img()` function to see if we get anything.
#
# $\textbf{NOTE}$: we only want to pass the characters in between the `<|image|>` separators, but WITHOUT the separators.

# %%
# TODO: split decoded message and extract text between <|image|> tags
b32_str = "DO THE SPLIT HERE"

Homework08_utils.b32_to_img(b32_str)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[17], line 4
#       1 # TODO: split decoded message and extract text between <|image|> tags
#       2 b32_str = "DO THE SPLIT HERE"
# ----> 4 Homework08_utils.b32_to_img(b32_str)
#
# File Homework08_utils.py:137, in b32_to_img(img_str)
#
# File /usr/local/lib/python3.10/base64.py:253, in b32decode(s, casefold, map01)
#     252 def b32decode(s, casefold=False, map01=None):
# --> 253     return _b32decode(_b32alphabet, s, casefold, map01)
#
# File /usr/local/lib/python3.10/base64.py:209, in _b32decode(alphabet, s, casefold, map01)
#     207 s = _bytes_from_decode_data(s)
#     208 if len(s) % 8:
# --> 209     raise binascii.Error('Incorrect padding')
#     210 # Handle section 2.4 zero and one mapping.  The flag map01 will be either
#     211 # False, or the character to map the digit 1 (one) to.  It should be
#     212 # either L (el) or I (eye).
#     213 if map01 is not None:
#
# Error: Incorrect padding

# %% [markdown]
# # 🪄⚡️
